# %% [markdown]
# __<center><h1>Chart__

# %%
 
import matplotlib
 
print(matplotlib.__version__)
# Out:
# 3.2.2

# %% [markdown]
# __<H2>Piechart__

# %% [markdown]
# __Starting at 0°__

# %%
import matplotlib.pyplot as plt
 
y =[35, 25, 45, 15]
mylabels = ["C", "C++", "Python", "java"]
 
plt.pie(y, labels = mylabels)
plt.show()

# %%
 import matplotlib.pyplot as plt
import numpy as np
 
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
 
plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# __Starting at 90°__

# %%
import matplotlib.pyplot as plt
y = [35, 25, 25, 15]
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
 
plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %% [markdown]
# __Legend__

# %%
import matplotlib.pyplot as plt
 
y =[35, 25, 45, 15]
mylabels = ["C", "C++", "Python", "java"]
 
plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
 import matplotlib.pyplot as plt
 
y =[35, 25, 45, 15]
mylabels = ["C", "C++", "Python", "java"]
 
plt.pie(y, labels = mylabels)
plt.legend(title="Coding")
plt.show()

# %% [markdown]
#  __Explode__

# %%
 import matplotlib.pyplot as plt
 
y =[35, 25, 45, 15]
mylabels = ["C", "C++", "Python", "java"]
x=[.2,0,0,0]
plt.pie(y, labels = mylabels, explode=x)
plt.show()

# %%
import matplotlib.pyplot as plt
 
y =[35, 25, 45, 15]
mylabels = ["C", "C++", "Python", "java"]
x=[.1,.1,.1,.1]
plt.pie(y, labels = mylabels, explode=x)
plt.show()

# %% [markdown]
# __<H2>Histogram__

# %%
 import matplotlib.pyplot as plt
x = [1,6,4,8]
plt.hist(x)
plt.show()

# %%
 import matplotlib.pyplot as plt
import numpy as np
 
x = np.random.normal(0, 10, 50)
 
plt.hist(x)
plt.show()

# %% [markdown]
#  __<H2>Barchart__

# %%
import matplotlib.pyplot as plt
 
y =[35, 25, 45, 15]
x = ["C", "C++", "Python", "java"]
 
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
 
y =[35, 25, 45, 15]
x = ["C", "C++", "Python", "java"]
 
plt.barh(x,y)
plt.show()

# %%
 import matplotlib.pyplot as plt
 
y =[35, 25, 45, 15]
x = ["C", "C++", "Python", "java"]
 
plt.bar(x,y,color="red")
plt.show()

# %%
 import matplotlib.pyplot as plt
y =[35, 25, 45, 15]
x = ["C", "C++", "Python", "java"]
z=["red","yellow","green","blue"]
plt.bar(x,y,color=z)
plt.show()

# %%
import matplotlib.pyplot as plt
 
y =[35, 25, 45, 15]
x = ["C", "C++", "Python", "java"]
 
plt.bar(x,y,width=.3)
plt.show()

# %%
 import matplotlib.pyplot as plt
 
y =[35, 25, 45, 15]
x = ["C", "C++", "Python", "java"]
 
plt.barh(x,y, height=.3)
plt.show()

# %% [markdown]
#  __<h2>Scatter__

# %%
import matplotlib.pyplot as plt
 
y =[35, 25, 45, 15]
x = ["C", "C++", "Python", "java"]
 
plt.scatter(x,y)
plt.show()

# %%
 import matplotlib.pyplot as plt
 
y =[35, 25, 45, 15]
x = [1,6,3,5]
plt.scatter(x,y)
y =[5, 25, 45, 75]
x = [3,4,1,7]
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
 
 
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
colors =[0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100]
 
plt.scatter(x, y, c=colors, cmap='viridis')
 
plt.colorbar()
 
plt.show()

# %%
import matplotlib.pyplot as plt
 
x = [80, 85, 90, 95, 100, 105, 110, 115, 120, 125]
y = [240, 250, 260, 270, 280, 290, 300, 310, 320, 330]
 
plt.title("Sports Watch Data\n")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
 
plt.plot(x, y)
 
plt.grid()
 
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints = [0, 6]
ypoints = [0, 250]
plt.plot(xpoints, ypoints)
plt.show()

# %%
 import matplotlib.pyplot as plt
xpoints = [1,9, 17,24]
ypoints = [10,48,5,56]
plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
#xpoints = [1,9, 17,24]
ypoints = [10,48,5,56]
plt.plot(ypoints)
plt.show()

# %%
 import matplotlib.pyplot as plt
#xpoints = [1,9, 17,24]
ypoints = [10,48,5,56]
plt.plot(ypoints,marker="o")
plt.show()

# %%
import matplotlib.pyplot as plt
#xpoints = [1,9, 17,24]
ypoints = [10,48,5,56]
plt.plot(ypoints,"o:r")
plt.show()

# %%
import matplotlib.pyplot as plt
#xpoints = [1,9, 17,24]
ypoints = [10,48,5,56]
plt.plot(ypoints,"1-b")
plt.show()

# %%
import matplotlib.pyplot as plt
#xpoints = [1,9, 17,24]
ypoints = [10,48,5,56]
plt.plot(ypoints,"1-b",ms=20)
plt.show()

# %%
 import matplotlib.pyplot as plt
#xpoints = [1,9, 17,24]
ypoints = [10,48,5,56]
plt.plot(ypoints,linewidth=20)
plt.show()

# %%
import matplotlib.pyplot as plt
#xpoints = [1,9, 17,24]
ypoints = [10,48,5,56]
plt.plot(ypoints,linestyle="dotted")
plt.show()
